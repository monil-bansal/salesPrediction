# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Data Preprocessing

# %%
data = pd.read_csv('./data.csv')

# %%
data.head()
# Out:
#        hh_id     weight        cms_zone  survey_mode    person_id  person_num  \
# 0  191546322    0.00000  Inner Brooklyn            1  19154632203           3
# 1  191546322    0.00000  Inner Brooklyn            1  19154632202           2
# 2  191546322  212.12729  Inner Brooklyn            1  19154632201           1
# 3   19241657    0.00000   Middle Queens            1   1924165703           3
# 4   19241657    0.00000   Middle Queens            1   1924165702           2
#
#    is_participant  num_days  num_days_complete  num_trips  num_walk_trips  \
# 0               0       NaN                NaN        NaN             NaN
# 1               0       NaN                NaN        NaN             NaN
# 2               1       7.0                7.0       23.0             1.0
# 3               0       NaN                NaN        NaN             NaN
# 4               0       NaN                NaN        NaN             NaN
#
# ...

# %%
data = data[data['is_participant']==1]

# %%
correlation = data.corr()

# %%
plt.plot(correlation)
plt.axis(False)
plt.show()

# %%
correlation
# Out:
#                              hh_id    weight  survey_mode  person_id  \
# hh_id                     1.000000  0.005595    -0.015767   1.000000
# weight                    0.005595  1.000000    -0.028688   0.005595
# survey_mode              -0.015767 -0.028688     1.000000  -0.015767
# person_id                 1.000000  0.005595    -0.015767   1.000000
# person_num                     NaN       NaN          NaN        NaN
# ...                            ...       ...          ...        ...
# disability_walking       -0.017526  0.042648     0.062125  -0.017526
# disability_mobility      -0.017513  0.042669     0.061949  -0.017513
# disability_dressing      -0.017507  0.042660     0.061933  -0.017507
# disability_concentrating -0.017513  0.042699     0.061929  -0.017513
# disability_none          -0.017452  0.042629     0.061615  -0.017452
#
#                           person_num  is_participant  num_days  \
# hh_id                            NaN             NaN  0.011599
# ...

# %%
#TO PRINT ALL COLUMNS
pd.options.display.max_columns = None

# %%
columnsToTake = ['weight','age','employment','worker','student','license','vehicle','harassment','gender','education','ethnicity','disability_none']
yCol = ['num_trips']

# %%
data_new = data[columnsToTake]

# %%
data_new.corr()
# Out:
#                    weight       age  employment    worker   student   license  \
# weight           1.000000  0.005426    0.006533 -0.026556 -0.014087 -0.001307
# age              0.005426  1.000000    0.327358 -0.344407 -0.303336  0.003759
# employment       0.006533  0.327358    1.000000 -0.900289  0.064508 -0.016826
# worker          -0.026556 -0.344407   -0.900289  1.000000 -0.026889 -0.001885
# student         -0.014087 -0.303336    0.064508 -0.026889  1.000000 -0.025947
# license         -0.001307  0.003759   -0.016826 -0.001885 -0.025947  1.000000
# vehicle         -0.000366 -0.167952    0.053047 -0.031150  0.059978 -0.178450
# harassment      -0.004734  0.042968    0.024290 -0.033692 -0.006429  0.560545
# gender           0.291814 -0.059671   -0.020177  0.014554  0.042031  0.013771
# education       -0.016898  0.022703    0.013973 -0.025177 -0.012972  0.666902
# ethnicity        0.110793 -0.113821   -0.020694  0.031941  0.079145 -0.054330
# ...

# %%
correlation = data_new.corr()

# %%
plt.plot(correlation)
plt.axis(True)
plt.show()

# %%
y = pd.DataFrame(y,dtype='int32')

# %%
x = np.array(data_new)

# %%
y = np.array(y)

# %%
x.shape
# Out:
# (3346, 12)

# %%
y = y.reshape(-1)

# %%
y.dtype
# Out:
# dtype('int32')

# %%
y.size
# Out:
# 3346

# %% [markdown]
# # Machine Learning Models

# %% [markdown]
# #### 1) Random Forests

# %%
from sklearn import tree

# %%
clf = tree.DecisionTreeRegressor()

# %%
from sklearn.model_selection import train_test_split
import numpy as np

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=42)

# %%
clf = clf.fit(X_train, y_train)

# %%
y_ = clf.predict(X_test)

# %%
np.sum(y_test == y_)/y_.size
# Out:
# 0.03582089552238806

# %%
y_train_ = clf.predict(X_train)

# %%
np.sum(y_train_ == y_train) / y_train.size
# Out:
# 0.9566517189835575

# %% [markdown]
# #### 2) Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
linearReg = LinearRegression()

# %%
linearReg = linearReg.fit(X_train,y_train)

# %%
y_train_ = linearReg.predict(X_train)

# %%
np.sum(y_train_==y_train)/y_train.size
# Out:
# 0.0

# %%
y_train_
# Out:
# array([20.62150665, 31.71059887, 24.21829031, ..., 30.21632662,
#        32.64841697, 10.28810832])

# %%
y_train
# Out:
# array([55, 34, 64, ..., 22,  3,  2])
